# %%
import yfinance as yf
from pandas_datareader.data import DataReader
from datetime import date

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlb = DataReader('xlb', 'yahoo', start=start)

#GET XLC RETURNS
xlb = xlb.reset_index()
xlb["Returns"] = xlb['Adj Close'].pct_change()
xlb.dropna(inplace=True)
xlb.to_csv('XLB.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlc = DataReader('xlc', 'yahoo', start=start)

#GET XLC RETURNS
xlc = xlc.reset_index()
xlc["Returns"] = xlc['Adj Close'].pct_change()
xlc.dropna(inplace=True)
xlc.to_csv('XLC.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xle = DataReader('xle', 'yahoo', start=start)

#GET XLC RETURNS
xle = xle.reset_index()
xle["Returns"] = xle['Adj Close'].pct_change()
xle.dropna(inplace=True)
xle.to_csv('XLE.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlf = DataReader('xlf', 'yahoo', start=start)

#GET XLC RETURNS
xlf = xlf.reset_index()
xlf["Returns"] = xlf['Adj Close'].pct_change()
xlf.dropna(inplace=True)
xlf.to_csv('XLF.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xli = DataReader('xli', 'yahoo', start=start)

#GET XLC RETURNS
xli = xli.reset_index()
xli["Returns"] = xli['Adj Close'].pct_change()
xli.dropna(inplace=True)
xli.to_csv('XLI.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlk = DataReader('xlk', 'yahoo', start=start)

#GET XLC RETURNS
xlk = xlk.reset_index()
xlk["Returns"] = xlk['Adj Close'].pct_change()
xlk.dropna(inplace=True)
xlk.to_csv('XLK.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlp = DataReader('xlp', 'yahoo', start=start)

#GET XLC RETURNS
xlp = xlp.reset_index()
xlp["Returns"] = xlp['Adj Close'].pct_change()
xlp.dropna(inplace=True)
xlp.to_csv('XLP.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlu = DataReader('xlu', 'yahoo', start=start)

#GET XLC RETURNS
xlu = xlu.reset_index()
xlu["Returns"] = xlu['Adj Close'].pct_change()
xlu.dropna(inplace=True)
xlu.to_csv('XLU.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xlv = DataReader('xlv', 'yahoo', start=start)

#GET XLC RETURNS
xlv= xlv.reset_index()
xlv["Returns"] = xlv['Adj Close'].pct_change()
xlv.dropna(inplace=True)
xlv.to_csv('XLV.csv')

# %%
#Get XL Returns
start = date(1998, 12, 21)
xly = DataReader('xly', 'yahoo', start=start)

#GET XLC RETURNS
xly = xly.reset_index()
xly["Returns"] = xly['Adj Close'].pct_change()
xly.dropna(inplace=True)
xly.to_csv('XLY.csv')

# %%
import operator
import os

import pandas as pd
import pytz

from qstrader.alpha_model.alpha_model import AlphaModel
from qstrader.alpha_model.fixed_signals import FixedSignalsAlphaModel
from qstrader.asset.equity import Equity
from qstrader.asset.universe.dynamic import DynamicUniverse
from qstrader.asset.universe.static import StaticUniverse
from qstrader.signals.momentum import MomentumSignal
from qstrader.signals.signals_collection import SignalsCollection
from qstrader.data.backtest_data_handler import BacktestDataHandler
from qstrader.data.daily_bar_csv import CSVDailyBarDataSource
from qstrader.statistics.tearsheet import TearsheetStatistics
from qstrader.trading.backtest import BacktestTradingSession


class TopNMomentumAlphaModel(AlphaModel):

    def __init__(
        self, signals, mom_lookback, mom_top_n, universe, data_handler
    ):
#         """
#         Initialise the TopNMomentumAlphaModel

#         Parameters
#         ----------
#         signals : `SignalsCollection`
#             The entity for interfacing with various pre-calculated
#             signals. In this instance we want to use 'momentum'.
#         mom_lookback : `integer`
#             The number of business days to calculate momentum
#             lookback over.
#         mom_top_n : `integer`
#             The number of assets to include in the portfolio,
#             ranking from highest momentum descending.
#         universe : `Universe`
#             The collection of assets utilised for signal generation.
#         data_handler : `DataHandler`
#             The interface to the CSV data.

#         Returns
#         -------
#         None
#         """
        self.signals = signals
        self.mom_lookback = mom_lookback
        self.mom_top_n = mom_top_n
        self.universe = universe
        self.data_handler = data_handler

    def _highest_momentum_asset(
        self, dt
    ):
#         """
#         Calculates the ordered list of highest performing momentum
#         assets restricted to the 'Top N', for a particular datetime.

#         Parameters
#         ----------
#         dt : `pd.Timestamp`
#             The datetime for which the highest momentum assets
#             should be calculated.

#         Returns
#         -------
#         `list[str]`
#             Ordered list of highest performing momentum assets
#             restricted to the 'Top N'.
#         """
        assets = self.signals['momentum'].assets

        # Calculate the holding-period return momenta for each asset,
        # for the particular provided momentum lookback period
        all_momenta = {
            asset: self.signals['momentum'](
                asset, self.mom_lookback
            ) for asset in assets
        }

        # Obtain a list of the top performing assets by momentum
        # restricted by the provided number of desired assets to
        # trade per month
        return [
            asset[0] for asset in sorted(
                all_momenta.items(),
                key=operator.itemgetter(1),
                reverse=True
            )
        ][:self.mom_top_n]

    def _generate_signals(
        self, dt, weights
    ):
#         """
#         Calculate the highest performing momentum for each
#         asset then assign 1 / N of the signal weight to each
#         of these assets.

#         Parameters
#         ----------
#         dt : `pd.Timestamp`
#             The datetime for which the signal weights
#             should be calculated.
#         weights : `dict{str: float}`
#             The current signal weights dictionary.

#         Returns
#         -------
#         `dict{str: float}`
#             The newly created signal weights dictionary.
#         """
        top_assets = self._highest_momentum_asset(dt)
        for asset in top_assets:
            weights[asset] = 1.0 / self.mom_top_n
        return weights

    def __call__(
        self, dt
    ):
#         """
#         Calculates the signal weights for the top N
#         momentum alpha model, assuming that there is
#         sufficient data to begin calculating momentum
#         on the desired assets.

#         Parameters
#         ----------
#         dt : `pd.Timestamp`
#             The datetime for which the signal weights
#             should be calculated.

#         Returns
#         -------
#         `dict{str: float}`
#             The newly created signal weights dictionary.
#         """
        assets = self.universe.get_assets(dt)
        weights = {asset: 0.0 for asset in assets}

        # Only generate weights if the current time exceeds the
        # momentum lookback period
        if self.signals.warmup >= self.mom_lookback:
            weights = self._generate_signals(dt, weights)
        return weights


if __name__ == "__main__":
    # Duration of the backtest
    start_dt = pd.Timestamp('1998-12-22 14:30:00', tz=pytz.UTC)
    burn_in_dt = pd.Timestamp('1999-12-22 14:30:00', tz=pytz.UTC)
    end_dt = pd.Timestamp('2010-12-31 23:59:00', tz=pytz.UTC)

    # Model parameters
    mom_lookback = 126  # Six months worth of business days
    mom_top_n = 3  # Number of assets to include at any one time

    # Construct the symbols and assets necessary for the backtest
    # This utilises the SPDR US sector ETFs, all beginning with XL
    strategy_symbols = ['XL%s' % sector for sector in "BCEFIKPUVY"]
    assets = ['EQ:%s' % symbol for symbol in strategy_symbols]

    # As this is a dynamic universe of assets (XLC is added later)
    # we need to tell QSTrader when XLC can be included. This is
    # achieved using an asset dates dictionary
    asset_dates = {asset: start_dt for asset in assets}
    asset_dates['EQ:XLC'] = pd.Timestamp('2018-06-18 00:00:00', tz=pytz.UTC)
    strategy_universe = DynamicUniverse(asset_dates)

    # To avoid loading all CSV files in the directory, set the
    # data source to load only those provided symbols
    csv_dir = os.environ.get('QSTRADER_CSV_DATA_DIR', '.')
    strategy_data_source = CSVDailyBarDataSource(csv_dir, Equity, csv_symbols=strategy_symbols)
    strategy_data_handler = BacktestDataHandler(strategy_universe, data_sources=[strategy_data_source])

    # Generate the signals (in this case holding-period return based
    # momentum) used in the top-N momentum alpha model
    momentum = MomentumSignal(start_dt, strategy_universe, lookbacks=[mom_lookback])
    signals = SignalsCollection({'momentum': momentum}, strategy_data_handler)

    # Generate the alpha model instance for the top-N momentum alpha model
    strategy_alpha_model = TopNMomentumAlphaModel(
        signals, mom_lookback, mom_top_n, strategy_universe, strategy_data_handler
    )

    # Construct the strategy backtest and run it
    strategy_backtest = BacktestTradingSession(
        start_dt,
        end_dt,
        strategy_universe,
        strategy_alpha_model,
        signals=signals,
        rebalance='end_of_month',
        long_only=True,
        cash_buffer_percentage=0.01,
        burn_in_dt=burn_in_dt,
        data_handler=strategy_data_handler
    )
    strategy_backtest.run()

    # Construct benchmark assets (buy & hold SPY)
    benchmark_symbols = ['SPY']
    benchmark_assets = ['EQ:SPY']
    benchmark_universe = StaticUniverse(benchmark_assets)
    benchmark_data_source = CSVDailyBarDataSource(csv_dir, Equity, csv_symbols=benchmark_symbols)
    benchmark_data_handler = BacktestDataHandler(benchmark_universe, data_sources=[benchmark_data_source])

    # Construct a benchmark Alpha Model that provides
    # 100% static allocation to the SPY ETF, with no rebalance
    benchmark_alpha_model = FixedSignalsAlphaModel({'EQ:SPY': 1.0})
    benchmark_backtest = BacktestTradingSession(
        burn_in_dt,
        end_dt,
        benchmark_universe,
        benchmark_alpha_model,
        rebalance='buy_and_hold',
        long_only=True,
        cash_buffer_percentage=0.01,
        data_handler=benchmark_data_handler
    )
    benchmark_backtest.run()

    # Performance Output
    tearsheet = TearsheetStatistics(
        strategy_equity=strategy_backtest.get_equity_curve(),
        benchmark_equity=benchmark_backtest.get_equity_curve(),
        title='US Sector Momentum - Top 3 Sectors'
    )
    tearsheet.plot_results()
# Out:
# Loading CSV files into DataFrames...
# Loading CSV file for symbol 'EQ:XLB'...
# Loading CSV file for symbol 'EQ:XLC'...
# Loading CSV file for symbol 'EQ:XLE'...
# Loading CSV file for symbol 'EQ:XLF'...
# Loading CSV file for symbol 'EQ:XLI'...
# Loading CSV file for symbol 'EQ:XLK'...
# Loading CSV file for symbol 'EQ:XLP'...
# Loading CSV file for symbol 'EQ:XLU'...
# Loading CSV file for symbol 'EQ:XLV'...
# Loading CSV file for symbol 'EQ:XLY'...
# Adjusting pricing in CSV files...
# Adjusting CSV file for symbol 'EQ:XLB'...
# Adjusting CSV file for symbol 'EQ:XLC'...
# Adjusting CSV file for symbol 'EQ:XLE'...
# Adjusting CSV file for symbol 'EQ:XLF'...
# Adjusting CSV file for symbol 'EQ:XLI'...
# Adjusting CSV file for symbol 'EQ:XLK'...
# Adjusting CSV file for symbol 'EQ:XLP'...
# Adjusting CSV file for symbol 'EQ:XLU'...
# Adjusting CSV file for symbol 'EQ:XLV'...
# Adjusting CSV file for symbol 'EQ:XLY'...
# Initialising simulated broker "Backtest Simulated Broker Account"...
# (1998-12-22 14:30:00+00:00) - portfolio creation: Portfolio "000001" created at broker "Backtest Simulated Broker Account"
# (1998-12-22 14:30:00+00:00) - subscription: 1000000.00 subscribed to portfolio "000001"
# Beginning backtest simulation...
# (1998-12-22 14:30:00+00:00) - market_open
# (1998-12-22 21:00:00+00:00) - market_close
# C:\Users\bng19\anaconda3_64bit\envs\QuantitativeTrading\lib\site-packages\qstrader\data\daily_bar_csv.py:219: FutureWarning: Passing method to DatetimeIndex.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   bid = bid_ask_df.iloc[bid_ask_df.index.get_loc(dt, method='pad')]['Bid']
# (1998-12-23 14:30:00+00:00) - market_open
# (1998-12-23 21:00:00+00:00) - market_close
# (1998-12-24 14:30:00+00:00) - market_open
# (1998-12-24 21:00:00+00:00) - market_close
# (1998-12-25 14:30:00+00:00) - market_open
# (1998-12-25 21:00:00+00:00) - market_close
# (1998-12-28 14:30:00+00:00) - market_open
# (1998-12-28 21:00:00+00:00) - market_close
# (1998-12-29 14:30:00+00:00) - market_open
# (1998-12-29 21:00:00+00:00) - market_close
# (1998-12-30 14:30:00+00:00) - market_open
# (1998-12-30 21:00:00+00:00) - market_close
# (1998-12-31 14:30:00+00:00) - market_open
# (1998-12-31 21:00:00+00:00) - market_close
# (1999-01-01 14:30:00+00:00) - market_open
# (1999-01-01 21:00:00+00:00) - market_close
# (1999-01-04 14:30:00+00:00) - market_open
# (1999-01-04 21:00:00+00:00) - market_close
# (1999-01-05 14:30:00+00:00) - market_open
# (1999-01-05 21:00:00+00:00) - market_close
# (1999-01-06 14:30:00+00:00) - market_open
# (1999-01-06 21:00:00+00:00) - market_close
# (1999-01-07 14:30:00+00:00) - market_open
# (1999-01-07 21:00:00+00:00) - market_close
# (1999-01-08 14:30:00+00:00) - market_open
# (1999-01-08 21:00:00+00:00) - market_close
# (1999-01-11 14:30:00+00:00) - market_open
# (1999-01-11 21:00:00+00:00) - market_close
# (1999-01-12 14:30:00+00:00) - market_open
# (1999-01-12 21:00:00+00:00) - market_close
# (1999-01-13 14:30:00+00:00) - market_open
# (1999-01-13 21:00:00+00:00) - market_close
# (1999-01-14 14:30:00+00:00) - market_open
# (1999-01-14 21:00:00+00:00) - market_close
# (1999-01-15 14:30:00+00:00) - market_open
# (1999-01-15 21:00:00+00:00) - market_close
# (1999-01-18 14:30:00+00:00) - market_open
# (1999-01-18 21:00:00+00:00) - market_close
# (1999-01-19 14:30:00+00:00) - market_open
# (1999-01-19 21:00:00+00:00) - market_close
# (1999-01-20 14:30:00+00:00) - market_open
# (1999-01-20 21:00:00+00:00) - market_close
# (1999-01-21 14:30:00+00:00) - market_open
# (1999-01-21 21:00:00+00:00) - market_close
# (1999-01-22 14:30:00+00:00) - market_open
# (1999-01-22 21:00:00+00:00) - market_close
# (1999-01-25 14:30:00+00:00) - market_open
# (1999-01-25 21:00:00+00:00) - market_close
# (1999-01-26 14:30:00+00:00) - market_open
# (1999-01-26 21:00:00+00:00) - market_close
# (1999-01-27 14:30:00+00:00) - market_open
# (1999-01-27 21:00:00+00:00) - market_close
# (1999-01-28 14:30:00+00:00) - market_open
# (1999-01-28 21:00:00+00:00) - market_close
# (1999-01-29 14:30:00+00:00) - market_open
# (1999-01-29 21:00:00+00:00) - market_close
# (1999-02-01 14:30:00+00:00) - market_open
# (1999-02-01 21:00:00+00:00) - market_close
# (1999-02-02 14:30:00+00:00) - market_open
# (1999-02-02 21:00:00+00:00) - market_close
# (1999-02-03 14:30:00+00:00) - market_open
# (1999-02-03 21:00:00+00:00) - market_close
# (1999-02-04 14:30:00+00:00) - market_open
# (1999-02-04 21:00:00+00:00) - market_close
# (1999-02-05 14:30:00+00:00) - market_open
# (1999-02-05 21:00:00+00:00) - market_close
# (1999-02-08 14:30:00+00:00) - market_open
# (1999-02-08 21:00:00+00:00) - market_close
# (1999-02-09 14:30:00+00:00) - market_open
# (1999-02-09 21:00:00+00:00) - market_close
# (1999-02-10 14:30:00+00:00) - market_open
# (1999-02-10 21:00:00+00:00) - market_close
# (1999-02-11 14:30:00+00:00) - market_open
# (1999-02-11 21:00:00+00:00) - market_close
# (1999-02-12 14:30:00+00:00) - market_open
# (1999-02-12 21:00:00+00:00) - market_close
# (1999-02-15 14:30:00+00:00) - market_open
# (1999-02-15 21:00:00+00:00) - market_close
# (1999-02-16 14:30:00+00:00) - market_open
# (1999-02-16 21:00:00+00:00) - market_close
# (1999-02-17 14:30:00+00:00) - market_open
# (1999-02-17 21:00:00+00:00) - market_close
# (1999-02-18 14:30:00+00:00) - market_open
# (1999-02-18 21:00:00+00:00) - market_close
# (1999-02-19 14:30:00+00:00) - market_open
# (1999-02-19 21:00:00+00:00) - market_close
# (1999-02-22 14:30:00+00:00) - market_open
# (1999-02-22 21:00:00+00:00) - market_close
# (1999-02-23 14:30:00+00:00) - market_open
# (1999-02-23 21:00:00+00:00) - market_close
# (1999-02-24 14:30:00+00:00) - market_open
# (1999-02-24 21:00:00+00:00) - market_close
# (1999-02-25 14:30:00+00:00) - market_open
# (1999-02-25 21:00:00+00:00) - market_close
# (1999-02-26 14:30:00+00:00) - market_open
# (1999-02-26 21:00:00+00:00) - market_close
# (1999-03-01 14:30:00+00:00) - market_open
# (1999-03-01 21:00:00+00:00) - market_close
# (1999-03-02 14:30:00+00:00) - market_open
# (1999-03-02 21:00:00+00:00) - market_close
# (1999-03-03 14:30:00+00:00) - market_open
# (1999-03-03 21:00:00+00:00) - market_close
# (1999-03-04 14:30:00+00:00) - market_open
# (1999-03-04 21:00:00+00:00) - market_close
# (1999-03-05 14:30:00+00:00) - market_open
# (1999-03-05 21:00:00+00:00) - market_close
# (1999-03-08 14:30:00+00:00) - market_open
# (1999-03-08 21:00:00+00:00) - market_close
# (1999-03-09 14:30:00+00:00) - market_open
# (1999-03-09 21:00:00+00:00) - market_close
# (1999-03-10 14:30:00+00:00) - market_open
# (1999-03-10 21:00:00+00:00) - market_close
# (1999-03-11 14:30:00+00:00) - market_open
# (1999-03-11 21:00:00+00:00) - market_close
# (1999-03-12 14:30:00+00:00) - market_open
# (1999-03-12 21:00:00+00:00) - market_close
# (1999-03-15 14:30:00+00:00) - market_open
# (1999-03-15 21:00:00+00:00) - market_close
# (1999-03-16 14:30:00+00:00) - market_open
# (1999-03-16 21:00:00+00:00) - market_close
# (1999-03-17 14:30:00+00:00) - market_open
# (1999-03-17 21:00:00+00:00) - market_close
# (1999-03-18 14:30:00+00:00) - market_open
# (1999-03-18 21:00:00+00:00) - market_close
# (1999-03-19 14:30:00+00:00) - market_open
# (1999-03-19 21:00:00+00:00) - market_close
# (1999-03-22 14:30:00+00:00) - market_open
# (1999-03-22 21:00:00+00:00) - market_close
# (1999-03-23 14:30:00+00:00) - market_open
# (1999-03-23 21:00:00+00:00) - market_close
# (1999-03-24 14:30:00+00:00) - market_open
# (1999-03-24 21:00:00+00:00) - market_close
# (1999-03-25 14:30:00+00:00) - market_open
# (1999-03-25 21:00:00+00:00) - market_close
# (1999-03-26 14:30:00+00:00) - market_open
# (1999-03-26 21:00:00+00:00) - market_close
# (1999-03-29 14:30:00+00:00) - market_open
# (1999-03-29 21:00:00+00:00) - market_close
# (1999-03-30 14:30:00+00:00) - market_open
# (1999-03-30 21:00:00+00:00) - market_close
# (1999-03-31 14:30:00+00:00) - market_open
# (1999-03-31 21:00:00+00:00) - market_close
# (1999-04-01 14:30:00+00:00) - market_open
# (1999-04-01 21:00:00+00:00) - market_close
# (1999-04-02 14:30:00+00:00) - market_open
# (1999-04-02 21:00:00+00:00) - market_close
# (1999-04-05 14:30:00+00:00) - market_open
# (1999-04-05 21:00:00+00:00) - market_close
# (1999-04-06 14:30:00+00:00) - market_open
# (1999-04-06 21:00:00+00:00) - market_close
# (1999-04-07 14:30:00+00:00) - market_open
# (1999-04-07 21:00:00+00:00) - market_close
# (1999-04-08 14:30:00+00:00) - market_open
# (1999-04-08 21:00:00+00:00) - market_close
# (1999-04-09 14:30:00+00:00) - market_open
# (1999-04-09 21:00:00+00:00) - market_close
# (1999-04-12 14:30:00+00:00) - market_open
# (1999-04-12 21:00:00+00:00) - market_close
# (1999-04-13 14:30:00+00:00) - market_open
# (1999-04-13 21:00:00+00:00) - market_close
# (1999-04-14 14:30:00+00:00) - market_open
# (1999-04-14 21:00:00+00:00) - market_close
# (1999-04-15 14:30:00+00:00) - market_open
# (1999-04-15 21:00:00+00:00) - market_close
# (1999-04-16 14:30:00+00:00) - market_open
# (1999-04-16 21:00:00+00:00) - market_close
# (1999-04-19 14:30:00+00:00) - market_open
# (1999-04-19 21:00:00+00:00) - market_close
# (1999-04-20 14:30:00+00:00) - market_open
# (1999-04-20 21:00:00+00:00) - market_close
# (1999-04-21 14:30:00+00:00) - market_open
# (1999-04-21 21:00:00+00:00) - market_close
# (1999-04-22 14:30:00+00:00) - market_open
# (1999-04-22 21:00:00+00:00) - market_close
# (1999-04-23 14:30:00+00:00) - market_open
# (1999-04-23 21:00:00+00:00) - market_close
# (1999-04-26 14:30:00+00:00) - market_open
# (1999-04-26 21:00:00+00:00) - market_close
# (1999-04-27 14:30:00+00:00) - market_open
# (1999-04-27 21:00:00+00:00) - market_close
# (1999-04-28 14:30:00+00:00) - market_open
# (1999-04-28 21:00:00+00:00) - market_close
# (1999-04-29 14:30:00+00:00) - market_open
# (1999-04-29 21:00:00+00:00) - market_close
# (1999-04-30 14:30:00+00:00) - market_open
# (1999-04-30 21:00:00+00:00) - market_close
# (1999-05-03 14:30:00+00:00) - market_open
# (1999-05-03 21:00:00+00:00) - market_close
# (1999-05-04 14:30:00+00:00) - market_open
# (1999-05-04 21:00:00+00:00) - market_close
# (1999-05-05 14:30:00+00:00) - market_open
# (1999-05-05 21:00:00+00:00) - market_close
# (1999-05-06 14:30:00+00:00) - market_open
# (1999-05-06 21:00:00+00:00) - market_close
# (1999-05-07 14:30:00+00:00) - market_open
# (1999-05-07 21:00:00+00:00) - market_close
# (1999-05-10 14:30:00+00:00) - market_open
# (1999-05-10 21:00:00+00:00) - market_close
# (1999-05-11 14:30:00+00:00) - market_open
# (1999-05-11 21:00:00+00:00) - market_close
# (1999-05-12 14:30:00+00:00) - market_open
# (1999-05-12 21:00:00+00:00) - market_close
# (1999-05-13 14:30:00+00:00) - market_open
# (1999-05-13 21:00:00+00:00) - market_close
# (1999-05-14 14:30:00+00:00) - market_open
# (1999-05-14 21:00:00+00:00) - market_close
# (1999-05-17 14:30:00+00:00) - market_open
# (1999-05-17 21:00:00+00:00) - market_close
# (1999-05-18 14:30:00+00:00) - market_open
# (1999-05-18 21:00:00+00:00) - market_close
# (1999-05-19 14:30:00+00:00) - market_open
# (1999-05-19 21:00:00+00:00) - market_close
# (1999-05-20 14:30:00+00:00) - market_open
# (1999-05-20 21:00:00+00:00) - market_close
# (1999-05-21 14:30:00+00:00) - market_open
# (1999-05-21 21:00:00+00:00) - market_close
# (1999-05-24 14:30:00+00:00) - market_open
# (1999-05-24 21:00:00+00:00) - market_close
# (1999-05-25 14:30:00+00:00) - market_open
# (1999-05-25 21:00:00+00:00) - market_close
# (1999-05-26 14:30:00+00:00) - market_open
# (1999-05-26 21:00:00+00:00) - market_close
# (1999-05-27 14:30:00+00:00) - market_open
# (1999-05-27 21:00:00+00:00) - market_close
# (1999-05-28 14:30:00+00:00) - market_open
# (1999-05-28 21:00:00+00:00) - market_close
# (1999-05-31 14:30:00+00:00) - market_open
# (1999-05-31 21:00:00+00:00) - market_close
# (1999-06-01 14:30:00+00:00) - market_open
# (1999-06-01 21:00:00+00:00) - market_close
# (1999-06-02 14:30:00+00:00) - market_open
# (1999-06-02 21:00:00+00:00) - market_close
# (1999-06-03 14:30:00+00:00) - market_open
# (1999-06-03 21:00:00+00:00) - market_close
# (1999-06-04 14:30:00+00:00) - market_open
# (1999-06-04 21:00:00+00:00) - market_close
# (1999-06-07 14:30:00+00:00) - market_open
# (1999-06-07 21:00:00+00:00) - market_close
# (1999-06-08 14:30:00+00:00) - market_open
# (1999-06-08 21:00:00+00:00) - market_close
# (1999-06-09 14:30:00+00:00) - market_open
# (1999-06-09 21:00:00+00:00) - market_close
# (1999-06-10 14:30:00+00:00) - market_open
# (1999-06-10 21:00:00+00:00) - market_close
# (1999-06-11 14:30:00+00:00) - market_open
# (1999-06-11 21:00:00+00:00) - market_close
# (1999-06-14 14:30:00+00:00) - market_open
# (1999-06-14 21:00:00+00:00) - market_close
# (1999-06-15 14:30:00+00:00) - market_open
# (1999-06-15 21:00:00+00:00) - market_close
# (1999-06-16 14:30:00+00:00) - market_open
# (1999-06-16 21:00:00+00:00) - market_close
# (1999-06-17 14:30:00+00:00) - market_open
# (1999-06-17 21:00:00+00:00) - market_close
# (1999-06-18 14:30:00+00:00) - market_open
# (1999-06-18 21:00:00+00:00) - market_close
# (1999-06-21 14:30:00+00:00) - market_open
# (1999-06-21 21:00:00+00:00) - market_close
# (1999-06-22 14:30:00+00:00) - market_open
# (1999-06-22 21:00:00+00:00) - market_close
# (1999-06-23 14:30:00+00:00) - market_open
# (1999-06-23 21:00:00+00:00) - market_close
# (1999-06-24 14:30:00+00:00) - market_open
# (1999-06-24 21:00:00+00:00) - market_close
# (1999-06-25 14:30:00+00:00) - market_open
# (1999-06-25 21:00:00+00:00) - market_close
# (1999-06-28 14:30:00+00:00) - market_open
# (1999-06-28 21:00:00+00:00) - market_close
# (1999-06-29 14:30:00+00:00) - market_open
# (1999-06-29 21:00:00+00:00) - market_close
# (1999-06-30 14:30:00+00:00) - market_open
# (1999-06-30 21:00:00+00:00) - market_close
# (1999-07-01 14:30:00+00:00) - market_open
# (1999-07-01 21:00:00+00:00) - market_close
# (1999-07-02 14:30:00+00:00) - market_open
# (1999-07-02 21:00:00+00:00) - market_close
# (1999-07-05 14:30:00+00:00) - market_open
# (1999-07-05 21:00:00+00:00) - market_close
# (1999-07-06 14:30:00+00:00) - market_open
# (1999-07-06 21:00:00+00:00) - market_close
# (1999-07-07 14:30:00+00:00) - market_open
# (1999-07-07 21:00:00+00:00) - market_close
# (1999-07-08 14:30:00+00:00) - market_open
# (1999-07-08 21:00:00+00:00) - market_close
# (1999-07-09 14:30:00+00:00) - market_open
# (1999-07-09 21:00:00+00:00) - market_close
# (1999-07-12 14:30:00+00:00) - market_open
# (1999-07-12 21:00:00+00:00) - market_close
# (1999-07-13 14:30:00+00:00) - market_open
# (1999-07-13 21:00:00+00:00) - market_close
# (1999-07-14 14:30:00+00:00) - market_open
# (1999-07-14 21:00:00+00:00) - market_close
# (1999-07-15 14:30:00+00:00) - market_open
# (1999-07-15 21:00:00+00:00) - market_close
# (1999-07-16 14:30:00+00:00) - market_open
# (1999-07-16 21:00:00+00:00) - market_close
# (1999-07-19 14:30:00+00:00) - market_open
# (1999-07-19 21:00:00+00:00) - market_close
# (1999-07-20 14:30:00+00:00) - market_open
# (1999-07-20 21:00:00+00:00) - market_close
# (1999-07-21 14:30:00+00:00) - market_open
# (1999-07-21 21:00:00+00:00) - market_close
# (1999-07-22 14:30:00+00:00) - market_open
# (1999-07-22 21:00:00+00:00) - market_close
# (1999-07-23 14:30:00+00:00) - market_open
# (1999-07-23 21:00:00+00:00) - market_close
# (1999-07-26 14:30:00+00:00) - market_open
# (1999-07-26 21:00:00+00:00) - market_close
# (1999-07-27 14:30:00+00:00) - market_open
# (1999-07-27 21:00:00+00:00) - market_close
# (1999-07-28 14:30:00+00:00) - market_open
# (1999-07-28 21:00:00+00:00) - market_close
# (1999-07-29 14:30:00+00:00) - market_open
# (1999-07-29 21:00:00+00:00) - market_close
# (1999-07-30 14:30:00+00:00) - market_open
# (1999-07-30 21:00:00+00:00) - market_close
# (1999-08-02 14:30:00+00:00) - market_open
# (1999-08-02 21:00:00+00:00) - market_close
# (1999-08-03 14:30:00+00:00) - market_open
# (1999-08-03 21:00:00+00:00) - market_close
# (1999-08-04 14:30:00+00:00) - market_open
# (1999-08-04 21:00:00+00:00) - market_close
# (1999-08-05 14:30:00+00:00) - market_open
# (1999-08-05 21:00:00+00:00) - market_close
# (1999-08-06 14:30:00+00:00) - market_open
# (1999-08-06 21:00:00+00:00) - market_close
# (1999-08-09 14:30:00+00:00) - market_open
# (1999-08-09 21:00:00+00:00) - market_close
# (1999-08-10 14:30:00+00:00) - market_open
# (1999-08-10 21:00:00+00:00) - market_close
# (1999-08-11 14:30:00+00:00) - market_open
# (1999-08-11 21:00:00+00:00) - market_close
# (1999-08-12 14:30:00+00:00) - market_open
# (1999-08-12 21:00:00+00:00) - market_close
# (1999-08-13 14:30:00+00:00) - market_open
# (1999-08-13 21:00:00+00:00) - market_close
# (1999-08-16 14:30:00+00:00) - market_open
# (1999-08-16 21:00:00+00:00) - market_close
# (1999-08-17 14:30:00+00:00) - market_open
# (1999-08-17 21:00:00+00:00) - market_close
# (1999-08-18 14:30:00+00:00) - market_open
# (1999-08-18 21:00:00+00:00) - market_close
# (1999-08-19 14:30:00+00:00) - market_open
# (1999-08-19 21:00:00+00:00) - market_close
# (1999-08-20 14:30:00+00:00) - market_open
# (1999-08-20 21:00:00+00:00) - market_close
# (1999-08-23 14:30:00+00:00) - market_open
# (1999-08-23 21:00:00+00:00) - market_close
# (1999-08-24 14:30:00+00:00) - market_open
# (1999-08-24 21:00:00+00:00) - market_close
# (1999-08-25 14:30:00+00:00) - market_open
# (1999-08-25 21:00:00+00:00) - market_close
# (1999-08-26 14:30:00+00:00) - market_open
# (1999-08-26 21:00:00+00:00) - market_close
# (1999-08-27 14:30:00+00:00) - market_open
# (1999-08-27 21:00:00+00:00) - market_close
# (1999-08-30 14:30:00+00:00) - market_open
# (1999-08-30 21:00:00+00:00) - market_close
# (1999-08-31 14:30:00+00:00) - market_open
# (1999-08-31 21:00:00+00:00) - market_close
# (1999-09-01 14:30:00+00:00) - market_open
# (1999-09-01 21:00:00+00:00) - market_close
# (1999-09-02 14:30:00+00:00) - market_open
# (1999-09-02 21:00:00+00:00) - market_close
# (1999-09-03 14:30:00+00:00) - market_open
# (1999-09-03 21:00:00+00:00) - market_close
# (1999-09-06 14:30:00+00:00) - market_open
# (1999-09-06 21:00:00+00:00) - market_close
# (1999-09-07 14:30:00+00:00) - market_open
# (1999-09-07 21:00:00+00:00) - market_close
# (1999-09-08 14:30:00+00:00) - market_open
# (1999-09-08 21:00:00+00:00) - market_close
# (1999-09-09 14:30:00+00:00) - market_open
# (1999-09-09 21:00:00+00:00) - market_close
# (1999-09-10 14:30:00+00:00) - market_open
# (1999-09-10 21:00:00+00:00) - market_close
# (1999-09-13 14:30:00+00:00) - market_open
# (1999-09-13 21:00:00+00:00) - market_close
# (1999-09-14 14:30:00+00:00) - market_open
# (1999-09-14 21:00:00+00:00) - market_close
# (1999-09-15 14:30:00+00:00) - market_open
# (1999-09-15 21:00:00+00:00) - market_close
# (1999-09-16 14:30:00+00:00) - market_open
# (1999-09-16 21:00:00+00:00) - market_close
# (1999-09-17 14:30:00+00:00) - market_open
# (1999-09-17 21:00:00+00:00) - market_close
# (1999-09-20 14:30:00+00:00) - market_open
# (1999-09-20 21:00:00+00:00) - market_close
# (1999-09-21 14:30:00+00:00) - market_open
# (1999-09-21 21:00:00+00:00) - market_close
# (1999-09-22 14:30:00+00:00) - market_open
# (1999-09-22 21:00:00+00:00) - market_close
# (1999-09-23 14:30:00+00:00) - market_open
# (1999-09-23 21:00:00+00:00) - market_close
# (1999-09-24 14:30:00+00:00) - market_open
# (1999-09-24 21:00:00+00:00) - market_close
# (1999-09-27 14:30:00+00:00) - market_open
# (1999-09-27 21:00:00+00:00) - market_close
# (1999-09-28 14:30:00+00:00) - market_open
# (1999-09-28 21:00:00+00:00) - market_close
# (1999-09-29 14:30:00+00:00) - market_open
# (1999-09-29 21:00:00+00:00) - market_close
# (1999-09-30 14:30:00+00:00) - market_open
# (1999-09-30 21:00:00+00:00) - market_close
# (1999-10-01 14:30:00+00:00) - market_open
# (1999-10-01 21:00:00+00:00) - market_close
# (1999-10-04 14:30:00+00:00) - market_open
# (1999-10-04 21:00:00+00:00) - market_close
# (1999-10-05 14:30:00+00:00) - market_open
# (1999-10-05 21:00:00+00:00) - market_close
# (1999-10-06 14:30:00+00:00) - market_open
# (1999-10-06 21:00:00+00:00) - market_close
# (1999-10-07 14:30:00+00:00) - market_open
# (1999-10-07 21:00:00+00:00) - market_close
# (1999-10-08 14:30:00+00:00) - market_open
# (1999-10-08 21:00:00+00:00) - market_close
# (1999-10-11 14:30:00+00:00) - market_open
# (1999-10-11 21:00:00+00:00) - market_close
# (1999-10-12 14:30:00+00:00) - market_open
# (1999-10-12 21:00:00+00:00) - market_close
# (1999-10-13 14:30:00+00:00) - market_open
# (1999-10-13 21:00:00+00:00) - market_close
# (1999-10-14 14:30:00+00:00) - market_open
# (1999-10-14 21:00:00+00:00) - market_close
# (1999-10-15 14:30:00+00:00) - market_open
# (1999-10-15 21:00:00+00:00) - market_close
# (1999-10-18 14:30:00+00:00) - market_open
# (1999-10-18 21:00:00+00:00) - market_close
# (1999-10-19 14:30:00+00:00) - market_open
# (1999-10-19 21:00:00+00:00) - market_close
# (1999-10-20 14:30:00+00:00) - market_open
# (1999-10-20 21:00:00+00:00) - market_close
# (1999-10-21 14:30:00+00:00) - market_open
# (1999-10-21 21:00:00+00:00) - market_close
# (1999-10-22 14:30:00+00:00) - market_open
# (1999-10-22 21:00:00+00:00) - market_close
# (1999-10-25 14:30:00+00:00) - market_open
# (1999-10-25 21:00:00+00:00) - market_close
# (1999-10-26 14:30:00+00:00) - market_open
# (1999-10-26 21:00:00+00:00) - market_close
# (1999-10-27 14:30:00+00:00) - market_open
# (1999-10-27 21:00:00+00:00) - market_close
# (1999-10-28 14:30:00+00:00) - market_open
# (1999-10-28 21:00:00+00:00) - market_close
# (1999-10-29 14:30:00+00:00) - market_open
# (1999-10-29 21:00:00+00:00) - market_close
# (1999-11-01 14:30:00+00:00) - market_open
# (1999-11-01 21:00:00+00:00) - market_close
# (1999-11-02 14:30:00+00:00) - market_open
# (1999-11-02 21:00:00+00:00) - market_close
# (1999-11-03 14:30:00+00:00) - market_open
# (1999-11-03 21:00:00+00:00) - market_close
# (1999-11-04 14:30:00+00:00) - market_open
# (1999-11-04 21:00:00+00:00) - market_close
# (1999-11-05 14:30:00+00:00) - market_open
# (1999-11-05 21:00:00+00:00) - market_close
# (1999-11-08 14:30:00+00:00) - market_open
# (1999-11-08 21:00:00+00:00) - market_close
# (1999-11-09 14:30:00+00:00) - market_open
# (1999-11-09 21:00:00+00:00) - market_close
# (1999-11-10 14:30:00+00:00) - market_open
# (1999-11-10 21:00:00+00:00) - market_close
# (1999-11-11 14:30:00+00:00) - market_open
# (1999-11-11 21:00:00+00:00) - market_close
# (1999-11-12 14:30:00+00:00) - market_open
# (1999-11-12 21:00:00+00:00) - market_close
# (1999-11-15 14:30:00+00:00) - market_open
# (1999-11-15 21:00:00+00:00) - market_close
# (1999-11-16 14:30:00+00:00) - market_open
# (1999-11-16 21:00:00+00:00) - market_close
# (1999-11-17 14:30:00+00:00) - market_open
# (1999-11-17 21:00:00+00:00) - market_close
# (1999-11-18 14:30:00+00:00) - market_open
# (1999-11-18 21:00:00+00:00) - market_close
# (1999-11-19 14:30:00+00:00) - market_open
# (1999-11-19 21:00:00+00:00) - market_close
# (1999-11-22 14:30:00+00:00) - market_open
# (1999-11-22 21:00:00+00:00) - market_close
# (1999-11-23 14:30:00+00:00) - market_open
# (1999-11-23 21:00:00+00:00) - market_close
# (1999-11-24 14:30:00+00:00) - market_open
# (1999-11-24 21:00:00+00:00) - market_close
# (1999-11-25 14:30:00+00:00) - market_open
# (1999-11-25 21:00:00+00:00) - market_close
# (1999-11-26 14:30:00+00:00) - market_open
# (1999-11-26 21:00:00+00:00) - market_close
# (1999-11-29 14:30:00+00:00) - market_open
# (1999-11-29 21:00:00+00:00) - market_close
# (1999-11-30 14:30:00+00:00) - market_open
# (1999-11-30 21:00:00+00:00) - market_close
# (1999-12-01 14:30:00+00:00) - market_open
# (1999-12-01 21:00:00+00:00) - market_close
# (1999-12-02 14:30:00+00:00) - market_open
# (1999-12-02 21:00:00+00:00) - market_close
# (1999-12-03 14:30:00+00:00) - market_open
# (1999-12-03 21:00:00+00:00) - market_close
# (1999-12-06 14:30:00+00:00) - market_open
# (1999-12-06 21:00:00+00:00) - market_close
# (1999-12-07 14:30:00+00:00) - market_open
# (1999-12-07 21:00:00+00:00) - market_close
# (1999-12-08 14:30:00+00:00) - market_open
# (1999-12-08 21:00:00+00:00) - market_close
# (1999-12-09 14:30:00+00:00) - market_open
# (1999-12-09 21:00:00+00:00) - market_close
# (1999-12-10 14:30:00+00:00) - market_open
# (1999-12-10 21:00:00+00:00) - market_close
# (1999-12-13 14:30:00+00:00) - market_open
# (1999-12-13 21:00:00+00:00) - market_close
# (1999-12-14 14:30:00+00:00) - market_open
# (1999-12-14 21:00:00+00:00) - market_close
# (1999-12-15 14:30:00+00:00) - market_open
# (1999-12-15 21:00:00+00:00) - market_close
# (1999-12-16 14:30:00+00:00) - market_open
# (1999-12-16 21:00:00+00:00) - market_close
# (1999-12-17 14:30:00+00:00) - market_open
# (1999-12-17 21:00:00+00:00) - market_close
# (1999-12-20 14:30:00+00:00) - market_open
# (1999-12-20 21:00:00+00:00) - market_close
# (1999-12-21 14:30:00+00:00) - market_open
# (1999-12-21 21:00:00+00:00) - market_close
# (1999-12-22 14:30:00+00:00) - market_open
# (1999-12-22 21:00:00+00:00) - market_close
# (1999-12-23 14:30:00+00:00) - market_open
# (1999-12-23 21:00:00+00:00) - market_close
# (1999-12-24 14:30:00+00:00) - market_open
# (1999-12-24 21:00:00+00:00) - market_close
# (1999-12-27 14:30:00+00:00) - market_open
# (1999-12-27 21:00:00+00:00) - market_close
# (1999-12-28 14:30:00+00:00) - market_open
# (1999-12-28 21:00:00+00:00) - market_close
# (1999-12-29 14:30:00+00:00) - market_open
# (1999-12-29 21:00:00+00:00) - market_close
# (1999-12-30 14:30:00+00:00) - market_open
# (1999-12-30 21:00:00+00:00) - market_close
# (1999-12-31 14:30:00+00:00) - market_open
# (1999-12-31 21:00:00+00:00) - market_close
# (1999-12-31 21:00:00+00:00) - trading logic and rebalance
# (1999-12-31 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.0, 'EQ:XLF': 0.0, 'EQ:XLI': 0.0, 'EQ:XLK': 0.3333333333333333, 'EQ:XLP': 0.0, 'EQ:XLU': 0.0, 'EQ:XLV': 0.3333333333333333, 'EQ:XLY': 0.3333333333333333}
# (1999-12-31 21:00:00+00:00) - submitted order: EQ:XLK, qty: 7981
# (1999-12-31 21:00:00+00:00) - submitted order: EQ:XLV, qty: 14820
# (1999-12-31 21:00:00+00:00) - submitted order: EQ:XLY, qty: 13861
# (2000-01-03 14:30:00+00:00) - market_open
# (2000-01-03 14:30:00+00:00) - executed order: EQ:XLK, qty: 7981, price: 42.69, consideration: 340703.00, commission: 0.00, total: 340703.00
# (2000-01-03 14:30:00+00:00) - executed order: EQ:XLV, qty: 14820, price: 22.35, consideration: 331162.00, commission: 0.00, total: 331162.00
# WARNING: Estimated transaction size of 329327.00 exceeds available cash of 328135.47. Transaction will still occur with a negative cash balance.
# WARNING: Not enough cash in the portfolio to carry out transaction. Transaction cost of 329326.7043674833 exceeds remaining cash of 328135.46676474717. Transaction will proceed with a negative cash balance.
# (2000-01-03 14:30:00+00:00) - executed order: EQ:XLY, qty: 13861, price: 23.76, consideration: 329327.00, commission: 0.00, total: 329327.00
# (2000-01-03 21:00:00+00:00) - market_close
# C:\Users\bng19\anaconda3_64bit\envs\QuantitativeTrading\lib\site-packages\qstrader\data\daily_bar_csv.py:243: FutureWarning: Passing method to DatetimeIndex.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   ask = bid_ask_df.iloc[bid_ask_df.index.get_loc(dt, method='pad')]['Ask']
# (2000-01-04 14:30:00+00:00) - market_open
# (2000-01-04 21:00:00+00:00) - market_close
# (2000-01-05 14:30:00+00:00) - market_open
# (2000-01-05 21:00:00+00:00) - market_close
# (2000-01-06 14:30:00+00:00) - market_open
# (2000-01-06 21:00:00+00:00) - market_close
# (2000-01-07 14:30:00+00:00) - market_open
# (2000-01-07 21:00:00+00:00) - market_close
# (2000-01-10 14:30:00+00:00) - market_open
# (2000-01-10 21:00:00+00:00) - market_close
# (2000-01-11 14:30:00+00:00) - market_open
# (2000-01-11 21:00:00+00:00) - market_close
# (2000-01-12 14:30:00+00:00) - market_open
# (2000-01-12 21:00:00+00:00) - market_close
# (2000-01-13 14:30:00+00:00) - market_open
# (2000-01-13 21:00:00+00:00) - market_close
# (2000-01-14 14:30:00+00:00) - market_open
# (2000-01-14 21:00:00+00:00) - market_close
# (2000-01-17 14:30:00+00:00) - market_open
# (2000-01-17 21:00:00+00:00) - market_close
# (2000-01-18 14:30:00+00:00) - market_open
# (2000-01-18 21:00:00+00:00) - market_close
# (2000-01-19 14:30:00+00:00) - market_open
# (2000-01-19 21:00:00+00:00) - market_close
# (2000-01-20 14:30:00+00:00) - market_open
# (2000-01-20 21:00:00+00:00) - market_close
# (2000-01-21 14:30:00+00:00) - market_open
# (2000-01-21 21:00:00+00:00) - market_close
# (2000-01-24 14:30:00+00:00) - market_open
# (2000-01-24 21:00:00+00:00) - market_close
# (2000-01-25 14:30:00+00:00) - market_open
# (2000-01-25 21:00:00+00:00) - market_close
# (2000-01-26 14:30:00+00:00) - market_open
# (2000-01-26 21:00:00+00:00) - market_close
# (2000-01-27 14:30:00+00:00) - market_open
# (2000-01-27 21:00:00+00:00) - market_close
# (2000-01-28 14:30:00+00:00) - market_open
# (2000-01-28 21:00:00+00:00) - market_close
# (2000-01-31 14:30:00+00:00) - market_open
# (2000-01-31 21:00:00+00:00) - market_close
# (2000-01-31 21:00:00+00:00) - trading logic and rebalance
# (2000-01-31 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.0, 'EQ:XLF': 0.0, 'EQ:XLI': 0.0, 'EQ:XLK': 0.3333333333333333, 'EQ:XLP': 0.0, 'EQ:XLU': 0.0, 'EQ:XLV': 0.3333333333333333, 'EQ:XLY': 0.3333333333333333}
# (2000-01-31 21:00:00+00:00) - submitted order: EQ:XLK, qty: -165
# (2000-01-31 21:00:00+00:00) - submitted order: EQ:XLV, qty: -845
# (2000-01-31 21:00:00+00:00) - submitted order: EQ:XLY, qty: 687
# (2000-02-01 14:30:00+00:00) - market_open
# (2000-02-01 14:30:00+00:00) - executed order: EQ:XLK, qty: -165, price: 38.77, consideration: -6397.00, commission: 0.00, total: -6397.00
# (2000-02-01 14:30:00+00:00) - executed order: EQ:XLV, qty: -845, price: 21.78, consideration: -18406.00, commission: 0.00, total: -18406.00
# (2000-02-01 14:30:00+00:00) - executed order: EQ:XLY, qty: 687, price: 21.03, consideration: 14447.00, commission: 0.00, total: 14447.00
# (2000-02-01 21:00:00+00:00) - market_close
# (2000-02-02 14:30:00+00:00) - market_open
# (2000-02-02 21:00:00+00:00) - market_close
# (2000-02-03 14:30:00+00:00) - market_open
# (2000-02-03 21:00:00+00:00) - market_close
# (2000-02-04 14:30:00+00:00) - market_open
# (2000-02-04 21:00:00+00:00) - market_close
# (2000-02-07 14:30:00+00:00) - market_open
# (2000-02-07 21:00:00+00:00) - market_close
# (2000-02-08 14:30:00+00:00) - market_open
# (2000-02-08 21:00:00+00:00) - market_close
# (2000-02-09 14:30:00+00:00) - market_open
# (2000-02-09 21:00:00+00:00) - market_close
# (2000-02-10 14:30:00+00:00) - market_open
# (2000-02-10 21:00:00+00:00) - market_close
# (2000-02-11 14:30:00+00:00) - market_open
# (2000-02-11 21:00:00+00:00) - market_close
# (2000-02-14 14:30:00+00:00) - market_open
# (2000-02-14 21:00:00+00:00) - market_close
# (2000-02-15 14:30:00+00:00) - market_open
# (2000-02-15 21:00:00+00:00) - market_close
# (2000-02-16 14:30:00+00:00) - market_open
# (2000-02-16 21:00:00+00:00) - market_close
# (2000-02-17 14:30:00+00:00) - market_open
# (2000-02-17 21:00:00+00:00) - market_close
# (2000-02-18 14:30:00+00:00) - market_open
# (2000-02-18 21:00:00+00:00) - market_close
# (2000-02-21 14:30:00+00:00) - market_open
# (2000-02-21 21:00:00+00:00) - market_close
# (2000-02-22 14:30:00+00:00) - market_open
# (2000-02-22 21:00:00+00:00) - market_close
# (2000-02-23 14:30:00+00:00) - market_open
# (2000-02-23 21:00:00+00:00) - market_close
# (2000-02-24 14:30:00+00:00) - market_open
# (2000-02-24 21:00:00+00:00) - market_close
# (2000-02-25 14:30:00+00:00) - market_open
# (2000-02-25 21:00:00+00:00) - market_close
# (2000-02-28 14:30:00+00:00) - market_open
# (2000-02-28 21:00:00+00:00) - market_close
# (2000-02-29 14:30:00+00:00) - market_open
# (2000-02-29 21:00:00+00:00) - market_close
# (2000-02-29 21:00:00+00:00) - trading logic and rebalance
# (2000-02-29 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.0, 'EQ:XLF': 0.0, 'EQ:XLI': 0.0, 'EQ:XLK': 0.3333333333333333, 'EQ:XLP': 0.0, 'EQ:XLU': 0.0, 'EQ:XLV': 0.3333333333333333, 'EQ:XLY': 0.3333333333333333}
# (2000-02-29 21:00:00+00:00) - submitted order: EQ:XLK, qty: -781.0
# (2000-02-29 21:00:00+00:00) - submitted order: EQ:XLV, qty: 897.0
# (2000-02-29 21:00:00+00:00) - submitted order: EQ:XLY, qty: 775
# (2000-03-01 14:30:00+00:00) - market_open
# (2000-03-01 14:30:00+00:00) - executed order: EQ:XLK, qty: -781.0, price: 42.98, consideration: -33565.00, commission: 0.00, total: -33565.00
# (2000-03-01 14:30:00+00:00) - executed order: EQ:XLV, qty: 897.0, price: 20.37, consideration: 18276.00, commission: 0.00, total: 18276.00
# (2000-03-01 14:30:00+00:00) - executed order: EQ:XLY, qty: 775, price: 19.70, consideration: 15267.00, commission: 0.00, total: 15267.00
# (2000-03-01 21:00:00+00:00) - market_close
# (2000-03-02 14:30:00+00:00) - market_open
# (2000-03-02 21:00:00+00:00) - market_close
# (2000-03-03 14:30:00+00:00) - market_open
# (2000-03-03 21:00:00+00:00) - market_close
# (2000-03-06 14:30:00+00:00) - market_open
# (2000-03-06 21:00:00+00:00) - market_close
# (2000-03-07 14:30:00+00:00) - market_open
# (2000-03-07 21:00:00+00:00) - market_close
# (2000-03-08 14:30:00+00:00) - market_open
# (2000-03-08 21:00:00+00:00) - market_close
# (2000-03-09 14:30:00+00:00) - market_open
# (2000-03-09 21:00:00+00:00) - market_close
# (2000-03-10 14:30:00+00:00) - market_open
# (2000-03-10 21:00:00+00:00) - market_close
# (2000-03-13 14:30:00+00:00) - market_open
# (2000-03-13 21:00:00+00:00) - market_close
# (2000-03-14 14:30:00+00:00) - market_open
# (2000-03-14 21:00:00+00:00) - market_close
# (2000-03-15 14:30:00+00:00) - market_open
# (2000-03-15 21:00:00+00:00) - market_close
# (2000-03-16 14:30:00+00:00) - market_open
# (2000-03-16 21:00:00+00:00) - market_close
# (2000-03-17 14:30:00+00:00) - market_open
# (2000-03-17 21:00:00+00:00) - market_close
# (2000-03-20 14:30:00+00:00) - market_open
# (2000-03-20 21:00:00+00:00) - market_close
# (2000-03-21 14:30:00+00:00) - market_open
# (2000-03-21 21:00:00+00:00) - market_close
# (2000-03-22 14:30:00+00:00) - market_open
# (2000-03-22 21:00:00+00:00) - market_close
# (2000-03-23 14:30:00+00:00) - market_open
# (2000-03-23 21:00:00+00:00) - market_close
# (2000-03-24 14:30:00+00:00) - market_open
# (2000-03-24 21:00:00+00:00) - market_close
# (2000-03-27 14:30:00+00:00) - market_open
# (2000-03-27 21:00:00+00:00) - market_close
# (2000-03-28 14:30:00+00:00) - market_open
# (2000-03-28 21:00:00+00:00) - market_close
# (2000-03-29 14:30:00+00:00) - market_open
# (2000-03-29 21:00:00+00:00) - market_close
# (2000-03-30 14:30:00+00:00) - market_open
# (2000-03-30 21:00:00+00:00) - market_close
# (2000-03-31 14:30:00+00:00) - market_open
# (2000-03-31 21:00:00+00:00) - market_close
# (2000-03-31 21:00:00+00:00) - trading logic and rebalance
# (2000-03-31 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.3333333333333333, 'EQ:XLF': 0.0, 'EQ:XLI': 0.0, 'EQ:XLK': 0.3333333333333333, 'EQ:XLP': 0.0, 'EQ:XLU': 0.0, 'EQ:XLV': 0.3333333333333333, 'EQ:XLY': 0.0}
# (2000-03-31 21:00:00+00:00) - submitted order: EQ:XLE, qty: 19640
# (2000-03-31 21:00:00+00:00) - submitted order: EQ:XLK, qty: 131.0
# (2000-03-31 21:00:00+00:00) - submitted order: EQ:XLV, qty: 193.0
# (2000-03-31 21:00:00+00:00) - submitted order: EQ:XLY, qty: -15323
# (2000-04-03 14:30:00+00:00) - market_open
# (2000-04-03 14:30:00+00:00) - executed order: EQ:XLY, qty: -15323, price: 22.77, consideration: -348961.00, commission: 0.00, total: -348961.00
# (2000-04-03 14:30:00+00:00) - executed order: EQ:XLE, qty: 19640, price: 17.07, consideration: 335210.00, commission: 0.00, total: 335210.00
# (2000-04-03 14:30:00+00:00) - executed order: EQ:XLK, qty: 131.0, price: 45.90, consideration: 6013.00, commission: 0.00, total: 6013.00
# (2000-04-03 14:30:00+00:00) - executed order: EQ:XLV, qty: 193.0, price: 22.29, consideration: 4302.00, commission: 0.00, total: 4302.00
# (2000-04-03 21:00:00+00:00) - market_close
# (2000-04-04 14:30:00+00:00) - market_open
# (2000-04-04 21:00:00+00:00) - market_close
# (2000-04-05 14:30:00+00:00) - market_open
# (2000-04-05 21:00:00+00:00) - market_close
# (2000-04-06 14:30:00+00:00) - market_open
# (2000-04-06 21:00:00+00:00) - market_close
# (2000-04-07 14:30:00+00:00) - market_open
# (2000-04-07 21:00:00+00:00) - market_close
# (2000-04-10 14:30:00+00:00) - market_open
# (2000-04-10 21:00:00+00:00) - market_close
# (2000-04-11 14:30:00+00:00) - market_open
# (2000-04-11 21:00:00+00:00) - market_close
# (2000-04-12 14:30:00+00:00) - market_open
# (2000-04-12 21:00:00+00:00) - market_close
# (2000-04-13 14:30:00+00:00) - market_open
# (2000-04-13 21:00:00+00:00) - market_close
# (2000-04-14 14:30:00+00:00) - market_open
# (2000-04-14 21:00:00+00:00) - market_close
# (2000-04-17 14:30:00+00:00) - market_open
# (2000-04-17 21:00:00+00:00) - market_close
# (2000-04-18 14:30:00+00:00) - market_open
# (2000-04-18 21:00:00+00:00) - market_close
# (2000-04-19 14:30:00+00:00) - market_open
# (2000-04-19 21:00:00+00:00) - market_close
# (2000-04-20 14:30:00+00:00) - market_open
# (2000-04-20 21:00:00+00:00) - market_close
# (2000-04-21 14:30:00+00:00) - market_open
# (2000-04-21 21:00:00+00:00) - market_close
# (2000-04-24 14:30:00+00:00) - market_open
# (2000-04-24 21:00:00+00:00) - market_close
# (2000-04-25 14:30:00+00:00) - market_open
# (2000-04-25 21:00:00+00:00) - market_close
# (2000-04-26 14:30:00+00:00) - market_open
# (2000-04-26 21:00:00+00:00) - market_close
# (2000-04-27 14:30:00+00:00) - market_open
# (2000-04-27 21:00:00+00:00) - market_close
# (2000-04-28 14:30:00+00:00) - market_open
# (2000-04-28 21:00:00+00:00) - market_close
# (2000-04-28 21:00:00+00:00) - trading logic and rebalance
# (2000-04-28 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.3333333333333333, 'EQ:XLF': 0.0, 'EQ:XLI': 0.3333333333333333, 'EQ:XLK': 0.3333333333333333, 'EQ:XLP': 0.0, 'EQ:XLU': 0.0, 'EQ:XLV': 0.0, 'EQ:XLY': 0.0}
# (2000-04-28 21:00:00+00:00) - submitted order: EQ:XLE, qty: -433
# (2000-04-28 21:00:00+00:00) - submitted order: EQ:XLI, qty: 16200
# (2000-04-28 21:00:00+00:00) - submitted order: EQ:XLK, qty: 436.0
# (2000-04-28 21:00:00+00:00) - submitted order: EQ:XLV, qty: -15065.0
# (2000-05-01 14:30:00+00:00) - market_open
# (2000-05-01 14:30:00+00:00) - executed order: EQ:XLE, qty: -433, price: 16.89, consideration: -7312.00, commission: 0.00, total: -7312.00
# (2000-05-01 14:30:00+00:00) - executed order: EQ:XLV, qty: -15065.0, price: 21.92, consideration: -330189.00, commission: 0.00, total: -330189.00
# (2000-05-01 14:30:00+00:00) - executed order: EQ:XLI, qty: 16200, price: 19.88, consideration: 322067.00, commission: 0.00, total: 322067.00
# (2000-05-01 14:30:00+00:00) - executed order: EQ:XLK, qty: 436.0, price: 42.83, consideration: 18675.00, commission: 0.00, total: 18675.00
# (2000-05-01 21:00:00+00:00) - market_close
# (2000-05-02 14:30:00+00:00) - market_open
# (2000-05-02 21:00:00+00:00) - market_close
# (2000-05-03 14:30:00+00:00) - market_open
# (2000-05-03 21:00:00+00:00) - market_close
# (2000-05-04 14:30:00+00:00) - market_open
# (2000-05-04 21:00:00+00:00) - market_close
# (2000-05-05 14:30:00+00:00) - market_open
# (2000-05-05 21:00:00+00:00) - market_close
# (2000-05-08 14:30:00+00:00) - market_open
# (2000-05-08 21:00:00+00:00) - market_close
# (2000-05-09 14:30:00+00:00) - market_open
# (2000-05-09 21:00:00+00:00) - market_close
# (2000-05-10 14:30:00+00:00) - market_open
# (2000-05-10 21:00:00+00:00) - market_close
# (2000-05-11 14:30:00+00:00) - market_open
# (2000-05-11 21:00:00+00:00) - market_close
# (2000-05-12 14:30:00+00:00) - market_open
# (2000-05-12 21:00:00+00:00) - market_close
# (2000-05-15 14:30:00+00:00) - market_open
# (2000-05-15 21:00:00+00:00) - market_close
# (2000-05-16 14:30:00+00:00) - market_open
# (2000-05-16 21:00:00+00:00) - market_close
# (2000-05-17 14:30:00+00:00) - market_open
# (2000-05-17 21:00:00+00:00) - market_close
# (2000-05-18 14:30:00+00:00) - market_open
# (2000-05-18 21:00:00+00:00) - market_close
# (2000-05-19 14:30:00+00:00) - market_open
# (2000-05-19 21:00:00+00:00) - market_close
# (2000-05-22 14:30:00+00:00) - market_open
# (2000-05-22 21:00:00+00:00) - market_close
# (2000-05-23 14:30:00+00:00) - market_open
# (2000-05-23 21:00:00+00:00) - market_close
# (2000-05-24 14:30:00+00:00) - market_open
# (2000-05-24 21:00:00+00:00) - market_close
# (2000-05-25 14:30:00+00:00) - market_open
# (2000-05-25 21:00:00+00:00) - market_close
# (2000-05-26 14:30:00+00:00) - market_open
# (2000-05-26 21:00:00+00:00) - market_close
# (2000-05-29 14:30:00+00:00) - market_open
# (2000-05-29 21:00:00+00:00) - market_close
# (2000-05-30 14:30:00+00:00) - market_open
# (2000-05-30 21:00:00+00:00) - market_close
# (2000-05-31 14:30:00+00:00) - market_open
# (2000-05-31 21:00:00+00:00) - market_close
# (2000-05-31 21:00:00+00:00) - trading logic and rebalance
# (2000-05-31 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.3333333333333333, 'EQ:XLF': 0.3333333333333333, 'EQ:XLI': 0.3333333333333333, 'EQ:XLK': 0.0, 'EQ:XLP': 0.0, 'EQ:XLU': 0.0, 'EQ:XLV': 0.0, 'EQ:XLY': 0.0}
# (2000-05-31 21:00:00+00:00) - submitted order: EQ:XLE, qty: -1972.0
# (2000-05-31 21:00:00+00:00) - submitted order: EQ:XLF, qty: 24608
# (2000-05-31 21:00:00+00:00) - submitted order: EQ:XLI, qty: 112
# (2000-05-31 21:00:00+00:00) - submitted order: EQ:XLK, qty: -7602.0
# (2000-06-01 14:30:00+00:00) - market_open
# (2000-06-01 14:30:00+00:00) - executed order: EQ:XLE, qty: -1972.0, price: 18.60, consideration: -36688.00, commission: 0.00, total: -36688.00
# (2000-06-01 14:30:00+00:00) - executed order: EQ:XLK, qty: -7602.0, price: 38.56, consideration: -293165.00, commission: 0.00, total: -293165.00
# (2000-06-01 14:30:00+00:00) - executed order: EQ:XLF, qty: 24608, price: 13.14, consideration: 323344.00, commission: 0.00, total: 323344.00
# (2000-06-01 14:30:00+00:00) - executed order: EQ:XLI, qty: 112, price: 19.76, consideration: 2213.00, commission: 0.00, total: 2213.00
# (2000-06-01 21:00:00+00:00) - market_close
# (2000-06-02 14:30:00+00:00) - market_open
# (2000-06-02 21:00:00+00:00) - market_close
# (2000-06-05 14:30:00+00:00) - market_open
# (2000-06-05 21:00:00+00:00) - market_close
# (2000-06-06 14:30:00+00:00) - market_open
# (2000-06-06 21:00:00+00:00) - market_close
# (2000-06-07 14:30:00+00:00) - market_open
# (2000-06-07 21:00:00+00:00) - market_close
# (2000-06-08 14:30:00+00:00) - market_open
# (2000-06-08 21:00:00+00:00) - market_close
# (2000-06-09 14:30:00+00:00) - market_open
# (2000-06-09 21:00:00+00:00) - market_close
# (2000-06-12 14:30:00+00:00) - market_open
# (2000-06-12 21:00:00+00:00) - market_close
# (2000-06-13 14:30:00+00:00) - market_open
# (2000-06-13 21:00:00+00:00) - market_close
# (2000-06-14 14:30:00+00:00) - market_open
# (2000-06-14 21:00:00+00:00) - market_close
# (2000-06-15 14:30:00+00:00) - market_open
# (2000-06-15 21:00:00+00:00) - market_close
# (2000-06-16 14:30:00+00:00) - market_open
# (2000-06-16 21:00:00+00:00) - market_close
# (2000-06-19 14:30:00+00:00) - market_open
# (2000-06-19 21:00:00+00:00) - market_close
# (2000-06-20 14:30:00+00:00) - market_open
# (2000-06-20 21:00:00+00:00) - market_close
# (2000-06-21 14:30:00+00:00) - market_open
# (2000-06-21 21:00:00+00:00) - market_close
# (2000-06-22 14:30:00+00:00) - market_open
# (2000-06-22 21:00:00+00:00) - market_close
# (2000-06-23 14:30:00+00:00) - market_open
# (2000-06-23 21:00:00+00:00) - market_close
# (2000-06-26 14:30:00+00:00) - market_open
# (2000-06-26 21:00:00+00:00) - market_close
# (2000-06-27 14:30:00+00:00) - market_open
# (2000-06-27 21:00:00+00:00) - market_close
# (2000-06-28 14:30:00+00:00) - market_open
# (2000-06-28 21:00:00+00:00) - market_close
# (2000-06-29 14:30:00+00:00) - market_open
# (2000-06-29 21:00:00+00:00) - market_close
# (2000-06-30 14:30:00+00:00) - market_open
# (2000-06-30 21:00:00+00:00) - market_close
# (2000-06-30 21:00:00+00:00) - trading logic and rebalance
# (2000-06-30 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.3333333333333333, 'EQ:XLF': 0.0, 'EQ:XLI': 0.0, 'EQ:XLK': 0.3333333333333333, 'EQ:XLP': 0.3333333333333333, 'EQ:XLU': 0.0, 'EQ:XLV': 0.0, 'EQ:XLY': 0.0}
# (2000-06-30 21:00:00+00:00) - submitted order: EQ:XLE, qty: 217.0
# (2000-06-30 21:00:00+00:00) - submitted order: EQ:XLF, qty: -24608
# (2000-06-30 21:00:00+00:00) - submitted order: EQ:XLI, qty: -16312
# (2000-06-30 21:00:00+00:00) - submitted order: EQ:XLK, qty: 7403
# (2000-06-30 21:00:00+00:00) - submitted order: EQ:XLP, qty: 20420
# (2000-07-03 14:30:00+00:00) - market_open
# (2000-07-03 14:30:00+00:00) - executed order: EQ:XLF, qty: -24608, price: 12.44, consideration: -306134.00, commission: 0.00, total: -306134.00
# (2000-07-03 14:30:00+00:00) - executed order: EQ:XLI, qty: -16312, price: 19.03, consideration: -310449.00, commission: 0.00, total: -310449.00
# (2000-07-03 14:30:00+00:00) - executed order: EQ:XLE, qty: 217.0, price: 17.55, consideration: 3808.00, commission: 0.00, total: 3808.00
# (2000-07-03 14:30:00+00:00) - executed order: EQ:XLK, qty: 7403, price: 41.49, consideration: 307151.00, commission: 0.00, total: 307151.00
# (2000-07-03 14:30:00+00:00) - executed order: EQ:XLP, qty: 20420, price: 14.98, consideration: 305951.00, commission: 0.00, total: 305951.00
# (2000-07-03 21:00:00+00:00) - market_close
# (2000-07-04 14:30:00+00:00) - market_open
# (2000-07-04 21:00:00+00:00) - market_close
# (2000-07-05 14:30:00+00:00) - market_open
# (2000-07-05 21:00:00+00:00) - market_close
# (2000-07-06 14:30:00+00:00) - market_open
# (2000-07-06 21:00:00+00:00) - market_close
# (2000-07-07 14:30:00+00:00) - market_open
# (2000-07-07 21:00:00+00:00) - market_close
# (2000-07-10 14:30:00+00:00) - market_open
# (2000-07-10 21:00:00+00:00) - market_close
# (2000-07-11 14:30:00+00:00) - market_open
# (2000-07-11 21:00:00+00:00) - market_close
# (2000-07-12 14:30:00+00:00) - market_open
# (2000-07-12 21:00:00+00:00) - market_close
# (2000-07-13 14:30:00+00:00) - market_open
# (2000-07-13 21:00:00+00:00) - market_close
# (2000-07-14 14:30:00+00:00) - market_open
# (2000-07-14 21:00:00+00:00) - market_close
# (2000-07-17 14:30:00+00:00) - market_open
# (2000-07-17 21:00:00+00:00) - market_close
# (2000-07-18 14:30:00+00:00) - market_open
# (2000-07-18 21:00:00+00:00) - market_close
# (2000-07-19 14:30:00+00:00) - market_open
# (2000-07-19 21:00:00+00:00) - market_close
# (2000-07-20 14:30:00+00:00) - market_open
# (2000-07-20 21:00:00+00:00) - market_close
# (2000-07-21 14:30:00+00:00) - market_open
# (2000-07-21 21:00:00+00:00) - market_close
# (2000-07-24 14:30:00+00:00) - market_open
# (2000-07-24 21:00:00+00:00) - market_close
# (2000-07-25 14:30:00+00:00) - market_open
# (2000-07-25 21:00:00+00:00) - market_close
# (2000-07-26 14:30:00+00:00) - market_open
# (2000-07-26 21:00:00+00:00) - market_close
# (2000-07-27 14:30:00+00:00) - market_open
# (2000-07-27 21:00:00+00:00) - market_close
# (2000-07-28 14:30:00+00:00) - market_open
# (2000-07-28 21:00:00+00:00) - market_close
# (2000-07-31 14:30:00+00:00) - market_open
# (2000-07-31 21:00:00+00:00) - market_close
# (2000-07-31 21:00:00+00:00) - trading logic and rebalance
# (2000-07-31 21:00:00+00:00) - target weights: {'EQ:XLB': 0.0, 'EQ:XLE': 0.3333333333333333, 'EQ:XLF': 0.3333333333333333, 'EQ:XLI': 0.0, 'EQ:XLK': 0.0, 'EQ:XLP': 0.3333333333333333, 'EQ:XLU': 0.0, 'EQ:XLV': 0.0, 'EQ:XLY': 0.0}
# (2000-07-31 21:00:00+00:00) - submitted order: EQ:XLE, qty: 4.0
# (2000-07-31 21:00:00+00:00) - submitted order: EQ:XLF, qty: 21881
# (2000-07-31 21:00:00+00:00) - submitted order: EQ:XLK, qty: -7403
# (2000-07-31 21:00:00+00:00) - submitted order: EQ:XLP, qty: -28
# (2000-08-01 14:30:00+00:00) - market_open
# (2000-08-01 14:30:00+00:00) - executed order: EQ:XLK, qty: -7403, price: 39.33, consideration: -291172.00, commission: 0.00, total: -291172.00
# (2000-08-01 14:30:00+00:00) - executed order: EQ:XLP, qty: -28, price: 14.59, consideration: -409.00, commission: 0.00, total: -409.00
# (2000-08-01 14:30:00+00:00) - executed order: EQ:XLE, qty: 4.0, price: 17.11, consideration: 68.00, commission: 0.00, total: 68.00
# (2000-08-01 14:30:00+00:00) - executed order: EQ:XLF, qty: 21881, price: 13.61, consideration: 297818.00, commission: 0.00, total: 297818.00
# (2000-08-01 21:00:00+00:00) - market_close
# (2000-08-02 14:30:00+00:00) - market_open
# (2000-08-02 21:00:00+00:00) - market_close
# (2000-08-03 14:30:00+00:00) - market_open
# (2000-08-03 21:00:00+00:00) - market_close
# (2000-08-04 14:30:00+00:00) - market_open
# (2000-08-04 21:00:00+00:00) - market_close
# (2000-08-07 14:30:00+00:00) - market_open
# (2000-08-07 21:00:00+00:00) - market_close
# (2000-08-08 14:30:00+00:00) - market_open
# (2000-08-08 21:00:00+00:00) - market_close
# (2000-08-09 14:30:00+00:00) - market_open
# (2000-08-09 21:00:00+00:00) - market_close
# (2000-08-10 14:30:00+00:00) - market_open
# (2000-08-10 21:00:00+00:00) - market_close
# (2000-08-11 14:30:00+00:00) - market_open
# (2000-08-11 21:00:00+00:00) - market_close
# (2000-08-14 14:30:00+00:00) - market_open
# (2000-08-14 21:00:00+00:00) - market_close
# (2000-08-15 14:30:00+00:00) - market_open
# (2000-08-15 21:00:00+00:00) - market_close
# (2000-08-16 14:30:00+00:00) - market_open
# (2000-08-16 21:00:00+00:00) - market_close
# (2000-08-17 14:30:00+00:00) - market_open
# (2000-08-17 21:00:00+00:00) - market_close
# (2000-08-18 14:30:00+00:00) - market_open
# (2000-08-18 21:00:00+00:00) - market_close
# (2000-08-21 14:30:00+00:00) - market_open
# (2000-08-21 21:00:00+00:00) - market_close
# (2000-08-22 14:30:00+00:00) - market_open
# (2000-08-22 21:00:00+00:00) - market_close
# (2000-08-23 14:30:00+00:00) - market_open
# (2000-08-23 21:00:00+00:00) - market_close
# (2000-08-24 14:30:00+00:00) - market_open
# (2000-08-24 21:00:00+00:00) - market_close
# (2000-08-25 14:30:00+00:00) - market_open
# ...
# (2010-04-14 21:00:00+00:00) - market_close
# (2010-04-15 14:30:00+00:00) - market_open
# (2010-04-15 21:00:00+00:00) - market_close
# (2010-04-16 14:30:00+00:00) - market_open
# (2010-04-16 21:00:00+00:00) - market_close
# (2010-04-19 14:30:00+00:00) - market_open
# (2010-04-19 21:00:00+00:00) - market_close
# (2010-04-20 14:30:00+00:00) - market_open
# (2010-04-20 21:00:00+00:00) - market_close
# (2010-04-21 14:30:00+00:00) - market_open
# (2010-04-21 21:00:00+00:00) - market_close
# (2010-04-22 14:30:00+00:00) - market_open
# (2010-04-22 21:00:00+00:00) - market_close
# (2010-04-23 14:30:00+00:00) - market_open
# (2010-04-23 21:00:00+00:00) - market_close
# (2010-04-26 14:30:00+00:00) - market_open
# (2010-04-26 21:00:00+00:00) - market_close
# (2010-04-27 14:30:00+00:00) - market_open
# (2010-04-27 21:00:00+00:00) - market_close
# (2010-04-28 14:30:00+00:00) - market_open
# (2010-04-28 21:00:00+00:00) - market_close
# (2010-04-29 14:30:00+00:00) - market_open
# (2010-04-29 21:00:00+00:00) - market_close
# (2010-04-30 14:30:00+00:00) - market_open
# (2010-04-30 21:00:00+00:00) - market_close
# (2010-05-03 14:30:00+00:00) - market_open
# (2010-05-03 21:00:00+00:00) - market_close
# (2010-05-04 14:30:00+00:00) - market_open
# (2010-05-04 21:00:00+00:00) - market_close
# (2010-05-05 14:30:00+00:00) - market_open
# (2010-05-05 21:00:00+00:00) - market_close
# (2010-05-06 14:30:00+00:00) - market_open
# (2010-05-06 21:00:00+00:00) - market_close
# (2010-05-07 14:30:00+00:00) - market_open
# (2010-05-07 21:00:00+00:00) - market_close
# (2010-05-10 14:30:00+00:00) - market_open
# (2010-05-10 21:00:00+00:00) - market_close
# (2010-05-11 14:30:00+00:00) - market_open
# (2010-05-11 21:00:00+00:00) - market_close
# (2010-05-12 14:30:00+00:00) - market_open
# (2010-05-12 21:00:00+00:00) - market_close
# (2010-05-13 14:30:00+00:00) - market_open
# (2010-05-13 21:00:00+00:00) - market_close
# (2010-05-14 14:30:00+00:00) - market_open
# (2010-05-14 21:00:00+00:00) - market_close
# (2010-05-17 14:30:00+00:00) - market_open
# (2010-05-17 21:00:00+00:00) - market_close
# (2010-05-18 14:30:00+00:00) - market_open
# (2010-05-18 21:00:00+00:00) - market_close
# (2010-05-19 14:30:00+00:00) - market_open
# (2010-05-19 21:00:00+00:00) - market_close
# (2010-05-20 14:30:00+00:00) - market_open
# (2010-05-20 21:00:00+00:00) - market_close
# (2010-05-21 14:30:00+00:00) - market_open
# (2010-05-21 21:00:00+00:00) - market_close
# (2010-05-24 14:30:00+00:00) - market_open
# (2010-05-24 21:00:00+00:00) - market_close
# (2010-05-25 14:30:00+00:00) - market_open
# (2010-05-25 21:00:00+00:00) - market_close
# (2010-05-26 14:30:00+00:00) - market_open
# (2010-05-26 21:00:00+00:00) - market_close
# (2010-05-27 14:30:00+00:00) - market_open
# (2010-05-27 21:00:00+00:00) - market_close
# (2010-05-28 14:30:00+00:00) - market_open
# (2010-05-28 21:00:00+00:00) - market_close
# (2010-05-31 14:30:00+00:00) - market_open
# (2010-05-31 21:00:00+00:00) - market_close
# (2010-06-01 14:30:00+00:00) - market_open
# (2010-06-01 21:00:00+00:00) - market_close
# (2010-06-02 14:30:00+00:00) - market_open
# (2010-06-02 21:00:00+00:00) - market_close
# (2010-06-03 14:30:00+00:00) - market_open
# (2010-06-03 21:00:00+00:00) - market_close
# (2010-06-04 14:30:00+00:00) - market_open
# (2010-06-04 21:00:00+00:00) - market_close
# (2010-06-07 14:30:00+00:00) - market_open
# (2010-06-07 21:00:00+00:00) - market_close
# (2010-06-08 14:30:00+00:00) - market_open
# (2010-06-08 21:00:00+00:00) - market_close
# (2010-06-09 14:30:00+00:00) - market_open
# (2010-06-09 21:00:00+00:00) - market_close
# (2010-06-10 14:30:00+00:00) - market_open
# (2010-06-10 21:00:00+00:00) - market_close
# (2010-06-11 14:30:00+00:00) - market_open
# (2010-06-11 21:00:00+00:00) - market_close
# (2010-06-14 14:30:00+00:00) - market_open
# (2010-06-14 21:00:00+00:00) - market_close
# (2010-06-15 14:30:00+00:00) - market_open
# (2010-06-15 21:00:00+00:00) - market_close
# (2010-06-16 14:30:00+00:00) - market_open
# (2010-06-16 21:00:00+00:00) - market_close
# (2010-06-17 14:30:00+00:00) - market_open
# (2010-06-17 21:00:00+00:00) - market_close
# (2010-06-18 14:30:00+00:00) - market_open
# (2010-06-18 21:00:00+00:00) - market_close
# (2010-06-21 14:30:00+00:00) - market_open
# (2010-06-21 21:00:00+00:00) - market_close
# (2010-06-22 14:30:00+00:00) - market_open
# (2010-06-22 21:00:00+00:00) - market_close
# (2010-06-23 14:30:00+00:00) - market_open
# (2010-06-23 21:00:00+00:00) - market_close
# (2010-06-24 14:30:00+00:00) - market_open
# (2010-06-24 21:00:00+00:00) - market_close
# (2010-06-25 14:30:00+00:00) - market_open
# (2010-06-25 21:00:00+00:00) - market_close
# (2010-06-28 14:30:00+00:00) - market_open
# (2010-06-28 21:00:00+00:00) - market_close
# (2010-06-29 14:30:00+00:00) - market_open
# (2010-06-29 21:00:00+00:00) - market_close
# (2010-06-30 14:30:00+00:00) - market_open
# (2010-06-30 21:00:00+00:00) - market_close
# (2010-07-01 14:30:00+00:00) - market_open
# (2010-07-01 21:00:00+00:00) - market_close
# (2010-07-02 14:30:00+00:00) - market_open
# (2010-07-02 21:00:00+00:00) - market_close
# (2010-07-05 14:30:00+00:00) - market_open
# (2010-07-05 21:00:00+00:00) - market_close
# (2010-07-06 14:30:00+00:00) - market_open
# (2010-07-06 21:00:00+00:00) - market_close
# (2010-07-07 14:30:00+00:00) - market_open
# (2010-07-07 21:00:00+00:00) - market_close
# (2010-07-08 14:30:00+00:00) - market_open
# (2010-07-08 21:00:00+00:00) - market_close
# (2010-07-09 14:30:00+00:00) - market_open
# (2010-07-09 21:00:00+00:00) - market_close
# (2010-07-12 14:30:00+00:00) - market_open
# (2010-07-12 21:00:00+00:00) - market_close
# (2010-07-13 14:30:00+00:00) - market_open
# (2010-07-13 21:00:00+00:00) - market_close
# (2010-07-14 14:30:00+00:00) - market_open
# (2010-07-14 21:00:00+00:00) - market_close
# (2010-07-15 14:30:00+00:00) - market_open
# (2010-07-15 21:00:00+00:00) - market_close
# (2010-07-16 14:30:00+00:00) - market_open
# (2010-07-16 21:00:00+00:00) - market_close
# (2010-07-19 14:30:00+00:00) - market_open
# (2010-07-19 21:00:00+00:00) - market_close
# (2010-07-20 14:30:00+00:00) - market_open
# (2010-07-20 21:00:00+00:00) - market_close
# (2010-07-21 14:30:00+00:00) - market_open
# (2010-07-21 21:00:00+00:00) - market_close
# (2010-07-22 14:30:00+00:00) - market_open
# (2010-07-22 21:00:00+00:00) - market_close
# (2010-07-23 14:30:00+00:00) - market_open
# (2010-07-23 21:00:00+00:00) - market_close
# (2010-07-26 14:30:00+00:00) - market_open
# (2010-07-26 21:00:00+00:00) - market_close
# (2010-07-27 14:30:00+00:00) - market_open
# (2010-07-27 21:00:00+00:00) - market_close
# (2010-07-28 14:30:00+00:00) - market_open
# (2010-07-28 21:00:00+00:00) - market_close
# (2010-07-29 14:30:00+00:00) - market_open
# (2010-07-29 21:00:00+00:00) - market_close
# (2010-07-30 14:30:00+00:00) - market_open
# (2010-07-30 21:00:00+00:00) - market_close
# (2010-08-02 14:30:00+00:00) - market_open
# (2010-08-02 21:00:00+00:00) - market_close
# (2010-08-03 14:30:00+00:00) - market_open
# (2010-08-03 21:00:00+00:00) - market_close
# (2010-08-04 14:30:00+00:00) - market_open
# (2010-08-04 21:00:00+00:00) - market_close
# (2010-08-05 14:30:00+00:00) - market_open
# (2010-08-05 21:00:00+00:00) - market_close
# (2010-08-06 14:30:00+00:00) - market_open
# (2010-08-06 21:00:00+00:00) - market_close
# (2010-08-09 14:30:00+00:00) - market_open
# (2010-08-09 21:00:00+00:00) - market_close
# (2010-08-10 14:30:00+00:00) - market_open
# (2010-08-10 21:00:00+00:00) - market_close
# (2010-08-11 14:30:00+00:00) - market_open
# (2010-08-11 21:00:00+00:00) - market_close
# (2010-08-12 14:30:00+00:00) - market_open
# (2010-08-12 21:00:00+00:00) - market_close
# (2010-08-13 14:30:00+00:00) - market_open
# (2010-08-13 21:00:00+00:00) - market_close
# (2010-08-16 14:30:00+00:00) - market_open
# (2010-08-16 21:00:00+00:00) - market_close
# (2010-08-17 14:30:00+00:00) - market_open
# (2010-08-17 21:00:00+00:00) - market_close
# (2010-08-18 14:30:00+00:00) - market_open
# (2010-08-18 21:00:00+00:00) - market_close
# (2010-08-19 14:30:00+00:00) - market_open
# (2010-08-19 21:00:00+00:00) - market_close
# (2010-08-20 14:30:00+00:00) - market_open
# (2010-08-20 21:00:00+00:00) - market_close
# (2010-08-23 14:30:00+00:00) - market_open
# (2010-08-23 21:00:00+00:00) - market_close
# (2010-08-24 14:30:00+00:00) - market_open
# (2010-08-24 21:00:00+00:00) - market_close
# (2010-08-25 14:30:00+00:00) - market_open
# (2010-08-25 21:00:00+00:00) - market_close
# (2010-08-26 14:30:00+00:00) - market_open
# (2010-08-26 21:00:00+00:00) - market_close
# (2010-08-27 14:30:00+00:00) - market_open
# (2010-08-27 21:00:00+00:00) - market_close
# (2010-08-30 14:30:00+00:00) - market_open
# (2010-08-30 21:00:00+00:00) - market_close
# (2010-08-31 14:30:00+00:00) - market_open
# (2010-08-31 21:00:00+00:00) - market_close
# (2010-09-01 14:30:00+00:00) - market_open
# (2010-09-01 21:00:00+00:00) - market_close
# (2010-09-02 14:30:00+00:00) - market_open
# (2010-09-02 21:00:00+00:00) - market_close
# (2010-09-03 14:30:00+00:00) - market_open
# (2010-09-03 21:00:00+00:00) - market_close
# (2010-09-06 14:30:00+00:00) - market_open
# (2010-09-06 21:00:00+00:00) - market_close
# (2010-09-07 14:30:00+00:00) - market_open
# (2010-09-07 21:00:00+00:00) - market_close
# (2010-09-08 14:30:00+00:00) - market_open
# (2010-09-08 21:00:00+00:00) - market_close
# (2010-09-09 14:30:00+00:00) - market_open
# (2010-09-09 21:00:00+00:00) - market_close
# (2010-09-10 14:30:00+00:00) - market_open
# (2010-09-10 21:00:00+00:00) - market_close
# (2010-09-13 14:30:00+00:00) - market_open
# (2010-09-13 21:00:00+00:00) - market_close
# (2010-09-14 14:30:00+00:00) - market_open
# (2010-09-14 21:00:00+00:00) - market_close
# (2010-09-15 14:30:00+00:00) - market_open
# (2010-09-15 21:00:00+00:00) - market_close
# (2010-09-16 14:30:00+00:00) - market_open
# (2010-09-16 21:00:00+00:00) - market_close
# (2010-09-17 14:30:00+00:00) - market_open
# (2010-09-17 21:00:00+00:00) - market_close
# (2010-09-20 14:30:00+00:00) - market_open
# (2010-09-20 21:00:00+00:00) - market_close
# (2010-09-21 14:30:00+00:00) - market_open
# (2010-09-21 21:00:00+00:00) - market_close
# (2010-09-22 14:30:00+00:00) - market_open
# (2010-09-22 21:00:00+00:00) - market_close
# (2010-09-23 14:30:00+00:00) - market_open
# (2010-09-23 21:00:00+00:00) - market_close
# (2010-09-24 14:30:00+00:00) - market_open
# (2010-09-24 21:00:00+00:00) - market_close
# (2010-09-27 14:30:00+00:00) - market_open
# (2010-09-27 21:00:00+00:00) - market_close
# (2010-09-28 14:30:00+00:00) - market_open
# (2010-09-28 21:00:00+00:00) - market_close
# (2010-09-29 14:30:00+00:00) - market_open
# (2010-09-29 21:00:00+00:00) - market_close
# (2010-09-30 14:30:00+00:00) - market_open
# (2010-09-30 21:00:00+00:00) - market_close
# (2010-10-01 14:30:00+00:00) - market_open
# (2010-10-01 21:00:00+00:00) - market_close
# (2010-10-04 14:30:00+00:00) - market_open
# (2010-10-04 21:00:00+00:00) - market_close
# (2010-10-05 14:30:00+00:00) - market_open
# (2010-10-05 21:00:00+00:00) - market_close
# (2010-10-06 14:30:00+00:00) - market_open
# (2010-10-06 21:00:00+00:00) - market_close
# (2010-10-07 14:30:00+00:00) - market_open
# (2010-10-07 21:00:00+00:00) - market_close
# (2010-10-08 14:30:00+00:00) - market_open
# (2010-10-08 21:00:00+00:00) - market_close
# (2010-10-11 14:30:00+00:00) - market_open
# (2010-10-11 21:00:00+00:00) - market_close
# (2010-10-12 14:30:00+00:00) - market_open
# (2010-10-12 21:00:00+00:00) - market_close
# (2010-10-13 14:30:00+00:00) - market_open
# (2010-10-13 21:00:00+00:00) - market_close
# (2010-10-14 14:30:00+00:00) - market_open
# (2010-10-14 21:00:00+00:00) - market_close
# (2010-10-15 14:30:00+00:00) - market_open
# (2010-10-15 21:00:00+00:00) - market_close
# (2010-10-18 14:30:00+00:00) - market_open
# (2010-10-18 21:00:00+00:00) - market_close
# (2010-10-19 14:30:00+00:00) - market_open
# (2010-10-19 21:00:00+00:00) - market_close
# (2010-10-20 14:30:00+00:00) - market_open
# (2010-10-20 21:00:00+00:00) - market_close
# (2010-10-21 14:30:00+00:00) - market_open
# (2010-10-21 21:00:00+00:00) - market_close
# (2010-10-22 14:30:00+00:00) - market_open
# (2010-10-22 21:00:00+00:00) - market_close
# (2010-10-25 14:30:00+00:00) - market_open
# (2010-10-25 21:00:00+00:00) - market_close
# (2010-10-26 14:30:00+00:00) - market_open
# (2010-10-26 21:00:00+00:00) - market_close
# (2010-10-27 14:30:00+00:00) - market_open
# (2010-10-27 21:00:00+00:00) - market_close
# (2010-10-28 14:30:00+00:00) - market_open
# (2010-10-28 21:00:00+00:00) - market_close
# (2010-10-29 14:30:00+00:00) - market_open
# (2010-10-29 21:00:00+00:00) - market_close
# (2010-11-01 14:30:00+00:00) - market_open
# (2010-11-01 21:00:00+00:00) - market_close
# (2010-11-02 14:30:00+00:00) - market_open
# (2010-11-02 21:00:00+00:00) - market_close
# (2010-11-03 14:30:00+00:00) - market_open
# (2010-11-03 21:00:00+00:00) - market_close
# (2010-11-04 14:30:00+00:00) - market_open
# (2010-11-04 21:00:00+00:00) - market_close
# (2010-11-05 14:30:00+00:00) - market_open
# (2010-11-05 21:00:00+00:00) - market_close
# (2010-11-08 14:30:00+00:00) - market_open
# (2010-11-08 21:00:00+00:00) - market_close
# (2010-11-09 14:30:00+00:00) - market_open
# (2010-11-09 21:00:00+00:00) - market_close
# (2010-11-10 14:30:00+00:00) - market_open
# (2010-11-10 21:00:00+00:00) - market_close
# (2010-11-11 14:30:00+00:00) - market_open
# (2010-11-11 21:00:00+00:00) - market_close
# (2010-11-12 14:30:00+00:00) - market_open
# (2010-11-12 21:00:00+00:00) - market_close
# (2010-11-15 14:30:00+00:00) - market_open
# (2010-11-15 21:00:00+00:00) - market_close
# (2010-11-16 14:30:00+00:00) - market_open
# (2010-11-16 21:00:00+00:00) - market_close
# (2010-11-17 14:30:00+00:00) - market_open
# (2010-11-17 21:00:00+00:00) - market_close
# (2010-11-18 14:30:00+00:00) - market_open
# (2010-11-18 21:00:00+00:00) - market_close
# (2010-11-19 14:30:00+00:00) - market_open
# (2010-11-19 21:00:00+00:00) - market_close
# (2010-11-22 14:30:00+00:00) - market_open
# (2010-11-22 21:00:00+00:00) - market_close
# (2010-11-23 14:30:00+00:00) - market_open
# (2010-11-23 21:00:00+00:00) - market_close
# (2010-11-24 14:30:00+00:00) - market_open
# (2010-11-24 21:00:00+00:00) - market_close
# (2010-11-25 14:30:00+00:00) - market_open
# (2010-11-25 21:00:00+00:00) - market_close
# (2010-11-26 14:30:00+00:00) - market_open
# (2010-11-26 21:00:00+00:00) - market_close
# (2010-11-29 14:30:00+00:00) - market_open
# (2010-11-29 21:00:00+00:00) - market_close
# (2010-11-30 14:30:00+00:00) - market_open
# (2010-11-30 21:00:00+00:00) - market_close
# (2010-12-01 14:30:00+00:00) - market_open
# (2010-12-01 21:00:00+00:00) - market_close
# (2010-12-02 14:30:00+00:00) - market_open
# (2010-12-02 21:00:00+00:00) - market_close
# (2010-12-03 14:30:00+00:00) - market_open
# (2010-12-03 21:00:00+00:00) - market_close
# (2010-12-06 14:30:00+00:00) - market_open
# (2010-12-06 21:00:00+00:00) - market_close
# (2010-12-07 14:30:00+00:00) - market_open
# (2010-12-07 21:00:00+00:00) - market_close
# (2010-12-08 14:30:00+00:00) - market_open
# (2010-12-08 21:00:00+00:00) - market_close
# (2010-12-09 14:30:00+00:00) - market_open
# (2010-12-09 21:00:00+00:00) - market_close
# (2010-12-10 14:30:00+00:00) - market_open
# (2010-12-10 21:00:00+00:00) - market_close
# (2010-12-13 14:30:00+00:00) - market_open
# (2010-12-13 21:00:00+00:00) - market_close
# (2010-12-14 14:30:00+00:00) - market_open
# (2010-12-14 21:00:00+00:00) - market_close
# (2010-12-15 14:30:00+00:00) - market_open
# (2010-12-15 21:00:00+00:00) - market_close
# (2010-12-16 14:30:00+00:00) - market_open
# (2010-12-16 21:00:00+00:00) - market_close
# (2010-12-17 14:30:00+00:00) - market_open
# (2010-12-17 21:00:00+00:00) - market_close
# (2010-12-20 14:30:00+00:00) - market_open
# (2010-12-20 21:00:00+00:00) - market_close
# (2010-12-21 14:30:00+00:00) - market_open
# (2010-12-21 21:00:00+00:00) - market_close
# (2010-12-22 14:30:00+00:00) - market_open
# (2010-12-22 21:00:00+00:00) - market_close
# (2010-12-23 14:30:00+00:00) - market_open
# (2010-12-23 21:00:00+00:00) - market_close
# (2010-12-24 14:30:00+00:00) - market_open
# (2010-12-24 21:00:00+00:00) - market_close
# (2010-12-27 14:30:00+00:00) - market_open
# (2010-12-27 21:00:00+00:00) - market_close
# (2010-12-28 14:30:00+00:00) - market_open
# (2010-12-28 21:00:00+00:00) - market_close
# (2010-12-29 14:30:00+00:00) - market_open
# (2010-12-29 21:00:00+00:00) - market_close
# (2010-12-30 14:30:00+00:00) - market_open
# (2010-12-30 21:00:00+00:00) - market_close
# (2010-12-31 14:30:00+00:00) - market_open
# (2010-12-31 21:00:00+00:00) - market_close
# Ending backtest simulation.
# Plotting the tearsheet...

# %%
print(strategy_data_source.csv_symbols
     )
# Out:
# ['XLB', 'XLC', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']

# %%
signals['momentum'].assets
# Out:
# ['EQ:XLB',
#  'EQ:XLE',
#  'EQ:XLF',
#  'EQ:XLI',
#  'EQ:XLK',
#  'EQ:XLP',
#  'EQ:XLU',
#  'EQ:XLV',
#  'EQ:XLY']

# %%
csv_dir
# Out:
# '.'
